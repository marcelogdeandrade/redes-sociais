# %% [markdown]
# # Encontro 06: Simulação de Negociações
#
# Importando a biblioteca:

# %%
import sys
sys.path.append('..')

import socnet as sn
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# Configurando a biblioteca:

# %%
sn.graph_width = 360
sn.graph_height = 360
sn.node_size = 25


def load_graph(path):
    g = sn.load_graph(path, has_pos=True)

    for n, m in g.edges():
        g.edge[n][m]['strong'] = bool(g.edge[n][m]['strong'])

    return g


def set_colors(g):
    for n, m in g.edges():
        if g.edge[n][m]['strong']:
            g.edge[n][m]['color'] = (0, 0, 0)
        else:
            g.edge[n][m]['color'] = (192, 192, 192)


def show_graph(g):
    set_colors(g)

    sn.show_graph(g, nlab=True)

# %% [markdown]
# O objetivo desta atividade é escrever uma simulação **animada** de negociações e executá-la sobre seis grafos diferentes.

# %% [markdown]
# Primeiro grafo:

# %%
g1 = load_graph('power-1.gml')

show_graph(g1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-be7d305e5b0e> in <module>()
# ----> 1 g1 = load_graph('power-1.gml')
#       2
#       3 show_graph(g1)
#
# <ipython-input-3-13fb1eee8209> in load_graph(path)
#       5
#       6 def load_graph(path):
# ----> 7     g = sn.load_graph(path, has_pos=True)
#       8
#       9     for n, m in g.edges():
#
# ~/Documents/Insper/6_Semestre/RedesSociais/redes-sociais/socnet.py in load_graph(path, has_pos)
#     242     g = networkx.read_gml(path, label='id')
#     243
# --> 244     reset_node_colors(g)
#     245     reset_edge_colors(g)
#     246
#
# ~/Documents/Insper/6_Semestre/RedesSociais/redes-sociais/socnet.py in reset_node_colors(g)
#     224
#     225 def reset_node_colors(g):
# --> 226     for n in g.nodes:
#     227         g.nodes[n]['color'] = node_color
#     228
#
# TypeError: 'method' object is not iterable

# %% [markdown]
# Segundo grafo:

# %%
g2 = load_graph('power-2.gml')

show_graph(g2)
# Out:
# <div id="e44bc827-58c0-4b00-bf3a-6a18f09e0351" style="height: 360px; width: 360px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("e44bc827-58c0-4b00-bf3a-6a18f09e0351", [{"hoverinfo": "none", "y": [0.4, 1.0, null, 0.4, 0.0, null, 0.4, 0.0, null, 1.0, 0.0, null, 1.0, 0.0, null, 0.0, 0.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 0.5, null, 0.5, 0.0, null, 0.5, 1.0, null, 0.5, 0.0, null, 0.5, 1.0, null, 0.0, 1.0, null]}, {"y": [0.4, 1.0, 0.0, 0.0], "x": [0.5, 0.5, 0.0, 1.0], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["C1", "C2", "C3", "C4"]}], {"showlegend": false, "margin": {"l": 0, "r": 0, "b": 0, "t": 0}, "yaxis": {"showgrid": false, "zeroline": false, "showticklabels": false}, "height": 360, "xaxis": {"showgrid": false, "zeroline": false, "showticklabels": false}, "width": 360}, {"linkText": "Export to plot.ly", "showLink": false, "displayModeBar": false})});</script>

# %% [markdown]
# Terceiro grafo:

# %%
g3 = load_graph('power-3.gml')

show_graph(g3)
# Out:
# <div id="6dc1c078-e0bd-4ef8-a179-8a4d205cf9ec" style="height: 360px; width: 360px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("6dc1c078-e0bd-4ef8-a179-8a4d205cf9ec", [{"hoverinfo": "none", "y": [0.0, 0.0, null], "line": {"color": "rgb(192, 192, 192)", "width": 2}, "mode": "lines", "x": [0.0, 1.0, null]}, {"hoverinfo": "none", "y": [1.0, 0.6, null, 1.0, 0.6, null, 0.6, 0.0, null, 0.6, 0.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 0.0, null, 0.5, 1.0, null, 0.0, 0.0, null, 1.0, 1.0, null]}, {"y": [1.0, 0.6, 0.6, 0.0, 0.0], "x": [0.5, 0.0, 1.0, 0.0, 1.0], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["D1", "E1", "E2", "F1", "F2"]}], {"showlegend": false, "margin": {"l": 0, "r": 0, "b": 0, "t": 0}, "yaxis": {"showgrid": false, "zeroline": false, "showticklabels": false}, "height": 360, "xaxis": {"showgrid": false, "zeroline": false, "showticklabels": false}, "width": 360}, {"linkText": "Export to plot.ly", "showLink": false, "displayModeBar": false})});</script>

# %% [markdown]
# Quarto grafo:

# %%
g4 = load_graph('power-4.gml')

show_graph(g4)
# Out:
# <div id="9dfc767e-3d5a-41fc-9729-afd8cbb7c0c5" style="height: 360px; width: 360px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("9dfc767e-3d5a-41fc-9729-afd8cbb7c0c5", [{"hoverinfo": "none", "y": [1.0, 0.0, null, 1.0, 0.0, null, 0.0, 0.0, null], "line": {"color": "rgb(192, 192, 192)", "width": 2}, "mode": "lines", "x": [0.5, 0.0, null, 0.5, 1.0, null, 0.0, 1.0, null]}, {"hoverinfo": "none", "y": [0.4, 0.7, null, 0.4, 0.2, null, 0.4, 0.2, null, 0.7, 1.0, null, 0.2, 0.0, null, 0.2, 0.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 0.5, null, 0.5, 0.25, null, 0.5, 0.75, null, 0.5, 0.5, null, 0.25, 0.0, null, 0.75, 1.0, null]}, {"y": [0.4, 0.7, 0.2, 0.2, 1.0, 0.0, 0.0], "x": [0.5, 0.5, 0.25, 0.75, 0.5, 0.0, 1.0], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["D2", "E3", "E4", "E5", "F3", "F4", "F5"]}], {"showlegend": false, "margin": {"l": 0, "r": 0, "b": 0, "t": 0}, "yaxis": {"showgrid": false, "zeroline": false, "showticklabels": false}, "height": 360, "xaxis": {"showgrid": false, "zeroline": false, "showticklabels": false}, "width": 360}, {"linkText": "Export to plot.ly", "showLink": false, "displayModeBar": false})});</script>

# %% [markdown]
# Quinto grafo:

# %%
g5 = load_graph('power-5.gml')

show_graph(g5)
# Out:
# <div id="c3a0d362-439b-498b-9b4a-9a818c32a7d7" style="height: 360px; width: 360px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("c3a0d362-439b-498b-9b4a-9a818c32a7d7", [{"hoverinfo": "none", "y": [1.0, 1.0, null, 1.0, 0.5, null, 1.0, 0.5, null, 0.5, 0.0, null, 0.0, 0.0, null, 0.5, 0.0, null], "line": {"color": "rgb(192, 192, 192)", "width": 2}, "mode": "lines", "x": [0.25, 0.75, null, 0.25, 0.0, null, 0.75, 1.0, null, 0.0, 0.25, null, 0.25, 0.75, null, 1.0, 0.75, null]}, {"hoverinfo": "none", "y": [0.5, 0.85, null, 0.5, 0.35, null, 0.5, 0.35, null, 0.85, 1.0, null, 0.85, 1.0, null, 0.35, 0.5, null, 0.35, 0.0, null, 0.35, 0.0, null, 0.35, 0.5, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 0.5, null, 0.5, 0.25, null, 0.5, 0.75, null, 0.5, 0.25, null, 0.5, 0.75, null, 0.25, 0.0, null, 0.25, 0.25, null, 0.75, 0.75, null, 0.75, 1.0, null]}, {"y": [0.5, 0.85, 0.35, 0.35, 1.0, 1.0, 0.5, 0.0, 0.5, 0.0], "x": [0.5, 0.5, 0.25, 0.75, 0.25, 0.75, 0.0, 0.25, 1.0, 0.75], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["D3", "E6", "E7", "E8", "F6", "F7", "F8", "F9", "F10", "F11"]}], {"showlegend": false, "margin": {"l": 0, "r": 0, "b": 0, "t": 0}, "yaxis": {"showgrid": false, "zeroline": false, "showticklabels": false}, "height": 360, "xaxis": {"showgrid": false, "zeroline": false, "showticklabels": false}, "width": 360}, {"linkText": "Export to plot.ly", "showLink": false, "displayModeBar": false})});</script>

# %% [markdown]
# Sexto grafo:

# %%
g6 = load_graph('power-6.gml')

show_graph(g6)
# Out:
# <div id="fe10c9eb-9fcc-4a0a-9905-8bb58e5ba6cb" style="height: 360px; width: 360px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("fe10c9eb-9fcc-4a0a-9905-8bb58e5ba6cb", [{"hoverinfo": "none", "y": [0.8, 1.0, null, 0.8, 0.5, null, 1.0, 0.8, null, 0.8, 0.5, null, 0.5, 0.1, null, 0.1, 0.0, null, 0.0, 0.0, null, 0.5, 0.1, null, 0.1, 0.0, null], "line": {"color": "rgb(192, 192, 192)", "width": 2}, "mode": "lines", "x": [0.25, 0.5, null, 0.25, 0.05, null, 0.5, 0.75, null, 0.75, 0.95, null, 0.05, 0.0, null, 0.0, 0.25, null, 0.25, 0.75, null, 0.95, 1.0, null, 1.0, 0.75, null]}, {"hoverinfo": "none", "y": [0.5, 0.75, null, 0.5, 0.25, null, 0.5, 0.25, null, 0.75, 0.8, null, 0.75, 1.0, null, 0.75, 0.8, null, 0.25, 0.1, null, 0.25, 0.0, null, 0.25, 0.5, null, 0.25, 0.5, null, 0.25, 0.1, null, 0.25, 0.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 0.5, null, 0.5, 0.25, null, 0.5, 0.75, null, 0.5, 0.25, null, 0.5, 0.5, null, 0.5, 0.75, null, 0.25, 0.0, null, 0.25, 0.25, null, 0.25, 0.05, null, 0.75, 0.95, null, 0.75, 1.0, null, 0.75, 0.75, null]}, {"y": [0.5, 0.75, 0.25, 0.25, 0.8, 1.0, 0.8, 0.5, 0.1, 0.0, 0.5, 0.1, 0.0], "x": [0.5, 0.5, 0.25, 0.75, 0.25, 0.5, 0.75, 0.05, 0.0, 0.25, 0.95, 1.0, 0.75], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["D4", "E9", "E10", "E11", "F12", "F13", "F14", "F15", "F16", "F17", "F18", "F19", "F20"]}], {"showlegend": false, "margin": {"l": 0, "r": 0, "b": 0, "t": 0}, "yaxis": {"showgrid": false, "zeroline": false, "showticklabels": false}, "height": 360, "xaxis": {"showgrid": false, "zeroline": false, "showticklabels": false}, "width": 360}, {"linkText": "Export to plot.ly", "showLink": false, "displayModeBar": false})});</script>

# %% [markdown]
# ## Definições
#
# * A **demanda** de um nó é um inteiro de $1$ a $23$.
#
# * A **oferta** de um nó $n$ para um nó $m$ é 24 menos a demanda de $n$ (se a aresta $\{n, m\}$ é forte) ou 8 menos a demanda de $n$ (se a aresta $\{n, m\}$ não é forte). Note que essa definição permite que a oferta seja negativa.
#
# * Um vizinho $m$ de $n$ é **aceitável** se a oferta de $m$ para $n$ é máxima em relação aos vizinhos de $n$ e maior ou igual que a demanda de $n$. Note que a segunda condição implica que um nó pode não ter vizinhos aceitáveis.
#
# ## Algoritmo
#
# 1. Inicialize a demanda de cada nó como um inteiro aleatório de $1$ a $23$.
#
# 2. Para cada nó $n$, escolha aleatoriamente um (e apenas um) vizinho aceitável $m$. Defina que $n$ aceita $m$. Se não tem vizinhos aceitáveis, defina que não aceita ninguém.
#
# 3. Para cada aresta $\{n, m\}$, defina que $n$ e $m$ fecharam se $n$ aceita $m$ e $m$ aceita $n$.
#
# 4. Para cada nó $n$, incremente a demanda (se fechou e a demanda é menor que $23$) ou decremente a demanda (se não fechou e a demanda é maior que $1$).
#
# 5. Repita os passos de 2 a 4 até as demandas convergirem.

# %%
from random import randint, choice

TIMES = 1000


def offer(g, n, m):
    if g.edge[n][m]['strong']:
        return 24 - g.node[m]['demand']
    return 8 - g.node[m]['demand']


def snapshot(g, frames):
    for n in g.nodes():
        g.node[n]['label'] = str(g.node[n]['demand'])
    frame = sn.generate_frame(g, nlab=True)
    frames.append(frame)


def simulate(g):
    frames = []
    
    # Parte 1
    for n in g.nodes():
        g.node[n]['demand'] = randint(1, 23)

    snapshot(g, frames)
    x = 0
    
    for _ in range(TIMES):
        #Reset
        for n in g.nodes():
            g.node[n]['accept'] = None
            g.node[n]['closed'] = False            
        # Parte 2
        for n in g.nodes():
            neighbors = g.neighbors(n)
            highest_offer = 0
            while neighbors:
                neighbor = choice(neighbors)
                current_offer = offer(g, neighbor, n)
                if current_offer > g.node[n]['demand'] and neighbor in neighbors and current_offer > highest_offer:
                    highest_offer = current_offer
                    g.node[n]['accept'] = neighbor
                if neighbor in neighbors:
                    neighbors.remove(neighbor)                     
        # Parte 3
        for n,m in g.edges_iter():
            if g.node[n]['accept'] == m and g.node[m]['accept'] == n:
                g.node[n]['closed'] = True
                g.node[m]['closed'] = True
                
        # Parte 4
        for n in g.nodes():
            if g.node[n]['closed'] and g.node[n]['demand'] < 23:
                g.node[n]['demand'] += 1
            elif not g.node[n]['closed'] and g.node[n]['demand'] > 1:
                g.node[n]['demand'] -= 1  
                
        # Animacao
        if x == 100:
            snapshot(g, frames)
            x = 0
        else:
            x += 1
    sn.show_animation(frames)


simulate(g3)
# Out:
# <div id="219fdfbc-8dda-4cd9-92bb-cee1562e0b5e" style="height: 436.0px; width: 450.0px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '219fdfbc-8dda-4cd9-92bb-cee1562e0b5e',
#             [{"hoverinfo": "none", "y": [1.0, 0.6, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 0.0, null]}, {"hoverinfo": "none", "y": [1.0, 0.6, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 1.0, null]}, {"hoverinfo": "none", "y": [0.6, 0.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.0, 0.0, null]}, {"hoverinfo": "none", "y": [0.6, 0.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [1.0, 1.0, null]}, {"hoverinfo": "none", "y": [0.0, 0.0, null], "line": {"color": "rgb(192, 192, 192)", "width": 2}, "mode": "lines", "x": [0.0, 1.0, null]}, {"y": [1.0], "x": [0.5], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["21"]}, {"y": [0.6], "x": [0.0], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["10"]}, {"y": [0.6], "x": [1.0], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["2"]}, {"y": [0.0], "x": [0.0], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["16"]}, {"y": [0.0], "x": [1.0], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["22"]}],
#             {"sliders": [{"currentvalue": {"visible": false}, "steps": [{"label": "", "args": [[0], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}, {"label": "", "args": [[1], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}, {"label": "", "args": [[2], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}, {"label": "", "args": [[3], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}, {"label": "", "args": [[4], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}, {"label": "", "args": [[5], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}, {"label": "", "args": [[6], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}, {"label": "", "args": [[7], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}, {"label": "", "args": [[8], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}, {"label": "", "args": [[9], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}]}], "showlegend": false, "margin": {"l": 0, "r": 0, "b": 0, "t": 0}, "yaxis": {"showgrid": false, "zeroline": false, "showticklabels": false}, "height": 436.0, "updatemenus": [{"buttons": [{"label": "Play", "args": [null, {"frame": {"redraw": false}, "fromcurrent": true}], "method": "animate"}, {"label": "Pause", "args": [[null], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}], "showactive": true, "type": "buttons"}], "xaxis": {"showgrid": false, "zeroline": false, "showticklabels": false}, "width": 450.0},
#             {"linkText": "Export to plot.ly", "showLink": false, "displayModeBar": false}
#         ).then(function () {return Plotly.addFrames('219fdfbc-8dda-4cd9-92bb-cee1562e0b5e',[{"data": [{"hoverinfo": "none", "y": [1.0, 0.6, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 0.0, null]}, {"hoverinfo": "none", "y": [1.0, 0.6, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 1.0, null]}, {"hoverinfo": "none", "y": [0.6, 0.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.0, 0.0, null]}, {"hoverinfo": "none", "y": [0.6, 0.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [1.0, 1.0, null]}, {"hoverinfo": "none", "y": [0.0, 0.0, null], "line": {"color": "rgb(192, 192, 192)", "width": 2}, "mode": "lines", "x": [0.0, 1.0, null]}, {"y": [1.0], "x": [0.5], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["21"]}, {"y": [0.6], "x": [0.0], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["10"]}, {"y": [0.6], "x": [1.0], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["2"]}, {"y": [0.0], "x": [0.0], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["16"]}, {"y": [0.0], "x": [1.0], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["22"]}], "name": 0}, {"data": [{"hoverinfo": "none", "y": [1.0, 0.6, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 0.0, null]}, {"hoverinfo": "none", "y": [1.0, 0.6, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 1.0, null]}, {"hoverinfo": "none", "y": [0.6, 0.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.0, 0.0, null]}, {"hoverinfo": "none", "y": [0.6, 0.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [1.0, 1.0, null]}, {"hoverinfo": "none", "y": [0.0, 0.0, null], "line": {"color": "rgb(192, 192, 192)", "width": 2}, "mode": "lines", "x": [0.0, 1.0, null]}, {"y": [1.0], "x": [0.5], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["1"]}, {"y": [0.6], "x": [0.0], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["11"]}, {"y": [0.6], "x": [1.0], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["12"]}, {"y": [0.0], "x": [0.0], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["2"]}, {"y": [0.0], "x": [1.0], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "lin

# %%
simulate(g1)
# Out:
# <div id="5d3a711a-a9d5-41c8-9797-07cb6f6d5a84" style="height: 436.0px; width: 450.0px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '5d3a711a-a9d5-41c8-9797-07cb6f6d5a84',
#             [{"hoverinfo": "none", "y": [0.4, 1.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 0.5, null]}, {"hoverinfo": "none", "y": [0.4, 0.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 0.0, null]}, {"hoverinfo": "none", "y": [0.4, 0.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 1.0, null]}, {"hoverinfo": "none", "y": [1.0, 0.0, null], "line": {"color": "rgb(192, 192, 192)", "width": 2}, "mode": "lines", "x": [0.5, 0.0, null]}, {"hoverinfo": "none", "y": [1.0, 0.0, null], "line": {"color": "rgb(192, 192, 192)", "width": 2}, "mode": "lines", "x": [0.5, 1.0, null]}, {"hoverinfo": "none", "y": [0.0, 0.0, null], "line": {"color": "rgb(192, 192, 192)", "width": 2}, "mode": "lines", "x": [0.0, 1.0, null]}, {"y": [0.4], "x": [0.5], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["14"]}, {"y": [1.0], "x": [0.5], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["17"]}, {"y": [0.0], "x": [0.0], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["14"]}, {"y": [0.0], "x": [1.0], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["23"]}],
#             {"sliders": [{"currentvalue": {"visible": false}, "steps": [{"label": "", "args": [[0], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}, {"label": "", "args": [[1], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}, {"label": "", "args": [[2], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}, {"label": "", "args": [[3], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}, {"label": "", "args": [[4], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}, {"label": "", "args": [[5], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}, {"label": "", "args": [[6], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}, {"label": "", "args": [[7], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}, {"label": "", "args": [[8], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}, {"label": "", "args": [[9], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}]}], "showlegend": false, "margin": {"l": 0, "r": 0, "b": 0, "t": 0}, "yaxis": {"showgrid": false, "zeroline": false, "showticklabels": false}, "height": 436.0, "updatemenus": [{"buttons": [{"label": "Play", "args": [null, {"frame": {"redraw": false}, "fromcurrent": true}], "method": "animate"}, {"label": "Pause", "args": [[null], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}], "showactive": true, "type": "buttons"}], "xaxis": {"showgrid": false, "zeroline": false, "showticklabels": false}, "width": 450.0},
#             {"linkText": "Export to plot.ly", "showLink": false, "displayModeBar": false}
#         ).then(function () {return Plotly.addFrames('5d3a711a-a9d5-41c8-9797-07cb6f6d5a84',[{"data": [{"hoverinfo": "none", "y": [0.4, 1.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 0.5, null]}, {"hoverinfo": "none", "y": [0.4, 0.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 0.0, null]}, {"hoverinfo": "none", "y": [0.4, 0.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 1.0, null]}, {"hoverinfo": "none", "y": [1.0, 0.0, null], "line": {"color": "rgb(192, 192, 192)", "width": 2}, "mode": "lines", "x": [0.5, 0.0, null]}, {"hoverinfo": "none", "y": [1.0, 0.0, null], "line": {"color": "rgb(192, 192, 192)", "width": 2}, "mode": "lines", "x": [0.5, 1.0, null]}, {"hoverinfo": "none", "y": [0.0, 0.0, null], "line": {"color": "rgb(192, 192, 192)", "width": 2}, "mode": "lines", "x": [0.0, 1.0, null]}, {"y": [0.4], "x": [0.5], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["14"]}, {"y": [1.0], "x": [0.5], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["17"]}, {"y": [0.0], "x": [0.0], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["14"]}, {"y": [0.0], "x": [1.0], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["23"]}], "name": 0}, {"data": [{"hoverinfo": "none", "y": [0.4, 1.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 0.5, null]}, {"hoverinfo": "none", "y": [0.4, 0.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 0.0, null]}, {"hoverinfo": "none", "y": [0.4, 0.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 1.0, null]}, {"hoverinfo": "none", "y": [1.0, 0.0, null], "line": {"color": "rgb(192, 192, 192)", "width": 2}, "mode": "lines", "x": [0.5, 0.0, null]}, {"hoverinfo": "none", "y": [1.0, 0.0, null], "line": {"color": "rgb(192, 192, 192)", "width": 2}, "mode": "lines", "x": [0.5, 1.0, null]}, {"hoverinfo": "none", "y": [0.0, 0.0, null], "line": {"color": "rgb(192, 192, 192)", "width": 2}, "mode": "lines", "x": [0.0, 1.0, null]}, {"y": [0.4], "x": [0.5], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["11"]}, {"y": [1.0], "x": [0.5], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["1"]}, {"y": [0.0], "x": [0.0], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["1"]}, {"y": [0.0], "x": [1.0], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["1"]}], "name": 1}, {"data": [{"hoverinfo": "none", "y": [0.4, 1.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 0.5, null]}, {" ...

# %%
simulate(g2)
# Out:
# <div id="278734dd-08ee-4dd9-8c52-452f1cd2438d" style="height: 436.0px; width: 450.0px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '278734dd-08ee-4dd9-8c52-452f1cd2438d',
#             [{"hoverinfo": "none", "y": [0.4, 1.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 0.5, null]}, {"hoverinfo": "none", "y": [0.4, 0.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 0.0, null]}, {"hoverinfo": "none", "y": [0.4, 0.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 1.0, null]}, {"hoverinfo": "none", "y": [1.0, 0.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 0.0, null]}, {"hoverinfo": "none", "y": [1.0, 0.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 1.0, null]}, {"hoverinfo": "none", "y": [0.0, 0.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.0, 1.0, null]}, {"y": [0.4], "x": [0.5], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["13"]}, {"y": [1.0], "x": [0.5], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["22"]}, {"y": [0.0], "x": [0.0], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["21"]}, {"y": [0.0], "x": [1.0], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["19"]}],
#             {"sliders": [{"currentvalue": {"visible": false}, "steps": [{"label": "", "args": [[0], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}, {"label": "", "args": [[1], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}, {"label": "", "args": [[2], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}, {"label": "", "args": [[3], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}, {"label": "", "args": [[4], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}, {"label": "", "args": [[5], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}, {"label": "", "args": [[6], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}, {"label": "", "args": [[7], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}, {"label": "", "args": [[8], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}, {"label": "", "args": [[9], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}]}], "showlegend": false, "margin": {"l": 0, "r": 0, "b": 0, "t": 0}, "yaxis": {"showgrid": false, "zeroline": false, "showticklabels": false}, "height": 436.0, "updatemenus": [{"buttons": [{"label": "Play", "args": [null, {"frame": {"redraw": false}, "fromcurrent": true}], "method": "animate"}, {"label": "Pause", "args": [[null], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}], "showactive": true, "type": "buttons"}], "xaxis": {"showgrid": false, "zeroline": false, "showticklabels": false}, "width": 450.0},
#             {"linkText": "Export to plot.ly", "showLink": false, "displayModeBar": false}
#         ).then(function () {return Plotly.addFrames('278734dd-08ee-4dd9-8c52-452f1cd2438d',[{"data": [{"hoverinfo": "none", "y": [0.4, 1.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 0.5, null]}, {"hoverinfo": "none", "y": [0.4, 0.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 0.0, null]}, {"hoverinfo": "none", "y": [0.4, 0.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 1.0, null]}, {"hoverinfo": "none", "y": [1.0, 0.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 0.0, null]}, {"hoverinfo": "none", "y": [1.0, 0.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 1.0, null]}, {"hoverinfo": "none", "y": [0.0, 0.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.0, 1.0, null]}, {"y": [0.4], "x": [0.5], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["13"]}, {"y": [1.0], "x": [0.5], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["22"]}, {"y": [0.0], "x": [0.0], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["21"]}, {"y": [0.0], "x": [1.0], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["19"]}], "name": 0}, {"data": [{"hoverinfo": "none", "y": [0.4, 1.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 0.5, null]}, {"hoverinfo": "none", "y": [0.4, 0.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 0.0, null]}, {"hoverinfo": "none", "y": [0.4, 0.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 1.0, null]}, {"hoverinfo": "none", "y": [1.0, 0.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 0.0, null]}, {"hoverinfo": "none", "y": [1.0, 0.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 1.0, null]}, {"hoverinfo": "none", "y": [0.0, 0.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.0, 1.0, null]}, {"y": [0.4], "x": [0.5], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["4"]}, {"y": [1.0], "x": [0.5], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["2"]}, {"y": [0.0], "x": [0.0], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["1"]}, {"y": [0.0], "x": [1.0], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["3"]}], "name": 1}, {"data": [{"hoverinfo": "none", "y": [0.4, 1.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 0.5, null]}, {"hoverinfo": "none", "y": [0.4, 0.0, n ...

# %% [markdown]
# O vídeo `exemplo.mp4` no repositório ilustra como a simulação deve ser: as negociações são destacadas e as demandas são atualizadas.

# %%
simulate(g4)
# Out:
# <div id="63498de9-c664-4baa-b514-0674221f2e4b" style="height: 436.0px; width: 450.0px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '63498de9-c664-4baa-b514-0674221f2e4b',
#             [{"hoverinfo": "none", "y": [0.4, 0.7, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 0.5, null]}, {"hoverinfo": "none", "y": [0.4, 0.2, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 0.25, null]}, {"hoverinfo": "none", "y": [0.4, 0.2, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 0.75, null]}, {"hoverinfo": "none", "y": [0.7, 1.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 0.5, null]}, {"hoverinfo": "none", "y": [0.2, 0.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.25, 0.0, null]}, {"hoverinfo": "none", "y": [0.2, 0.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.75, 1.0, null]}, {"hoverinfo": "none", "y": [1.0, 0.0, null], "line": {"color": "rgb(192, 192, 192)", "width": 2}, "mode": "lines", "x": [0.5, 0.0, null]}, {"hoverinfo": "none", "y": [1.0, 0.0, null], "line": {"color": "rgb(192, 192, 192)", "width": 2}, "mode": "lines", "x": [0.5, 1.0, null]}, {"hoverinfo": "none", "y": [0.0, 0.0, null], "line": {"color": "rgb(192, 192, 192)", "width": 2}, "mode": "lines", "x": [0.0, 1.0, null]}, {"y": [0.4], "x": [0.5], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["13"]}, {"y": [0.7], "x": [0.5], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["10"]}, {"y": [0.2], "x": [0.25], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["2"]}, {"y": [0.2], "x": [0.75], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["21"]}, {"y": [1.0], "x": [0.5], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["2"]}, {"y": [0.0], "x": [0.0], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["7"]}, {"y": [0.0], "x": [1.0], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["1"]}],
#             {"sliders": [{"currentvalue": {"visible": false}, "steps": [{"label": "", "args": [[0], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}, {"label": "", "args": [[1], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}, {"label": "", "args": [[2], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}, {"label": "", "args": [[3], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}, {"label": "", "args": [[4], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}, {"label": "", "args": [[5], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}, {"label": "", "args": [[6], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}, {"label": "", "args": [[7], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}, {"label": "", "args": [[8], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}, {"label": "", "args": [[9], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}]}], "showlegend": false, "margin": {"l": 0, "r": 0, "b": 0, "t": 0}, "yaxis": {"showgrid": false, "zeroline": false, "showticklabels": false}, "height": 436.0, "updatemenus": [{"buttons": [{"label": "Play", "args": [null, {"frame": {"redraw": false}, "fromcurrent": true}], "method": "animate"}, {"label": "Pause", "args": [[null], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}], "showactive": true, "type": "buttons"}], "xaxis": {"showgrid": false, "zeroline": false, "showticklabels": false}, "width": 450.0},
#             {"linkText": "Export to plot.ly", "showLink": false, "displayModeBar": false}
#         ).then(function () {return Plotly.addFrames('63498de9-c664-4baa-b514-0674221f2e4b',[{"data": [{"hoverinfo": "none", "y": [0.4, 0.7, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 0.5, null]}, {"hoverinfo": "none", "y": [0.4, 0.2, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 0.25, null]}, {"hoverinfo": "none", "y": [0.4, 0.2, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 0.75, null]}, {"hoverinfo": "none", "y": [0.7, 1.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 0.5, null]}, {"hoverinfo": "none", "y": [0.2, 0.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.25, 0.0, null]}, {"hoverinfo": "none", "y": [0.2, 0.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.75, 1.0, null]}, {"hoverinfo": "none", "y": [1.0, 0.0, null], "line": {"color": "rgb(192, 192, 192)", "width": 2}, "mode": "lines", "x": [0.5, 0.0, null]}, {"hoverinfo": "none", "y": [1.0, 0.0, null], "line": {"color": "rgb(192, 192, 192)", "width": 2}, "mode": "lines", "x": [0.5, 1.0, null]}, {"hoverinfo": "none", "y": [0.0, 0.0, null], "line": {"color": "rgb(192, 192, 192)", "width": 2}, "mode": "lines", "x": [0.0, 1.0, null]}, {"y": [0.4], "x": [0.5], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["13"]}, {"y": [0.7], "x": [0.5], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["10"]}, {"y": [0.2], "x": [0.25], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["2"]}, {"y": [0.2], "x": [0.75], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["21"]}, {"y": [1.0], "x": [0.5], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["2"]}, {"y": [0.0], "x": [0.0], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text

# %%
simulate(g5)
# Out:
# <div id="673c3568-6fc2-4bb6-b922-c53ee02bdfeb" style="height: 436.0px; width: 450.0px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '673c3568-6fc2-4bb6-b922-c53ee02bdfeb',
#             [{"hoverinfo": "none", "y": [0.5, 0.85, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 0.5, null]}, {"hoverinfo": "none", "y": [0.5, 0.35, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 0.25, null]}, {"hoverinfo": "none", "y": [0.5, 0.35, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 0.75, null]}, {"hoverinfo": "none", "y": [0.85, 1.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 0.25, null]}, {"hoverinfo": "none", "y": [0.85, 1.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 0.75, null]}, {"hoverinfo": "none", "y": [0.35, 0.5, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.25, 0.0, null]}, {"hoverinfo": "none", "y": [0.35, 0.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.25, 0.25, null]}, {"hoverinfo": "none", "y": [0.35, 0.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.75, 0.75, null]}, {"hoverinfo": "none", "y": [0.35, 0.5, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.75, 1.0, null]}, {"hoverinfo": "none", "y": [1.0, 1.0, null], "line": {"color": "rgb(192, 192, 192)", "width": 2}, "mode": "lines", "x": [0.25, 0.75, null]}, {"hoverinfo": "none", "y": [1.0, 0.5, null], "line": {"color": "rgb(192, 192, 192)", "width": 2}, "mode": "lines", "x": [0.25, 0.0, null]}, {"hoverinfo": "none", "y": [1.0, 0.5, null], "line": {"color": "rgb(192, 192, 192)", "width": 2}, "mode": "lines", "x": [0.75, 1.0, null]}, {"hoverinfo": "none", "y": [0.5, 0.0, null], "line": {"color": "rgb(192, 192, 192)", "width": 2}, "mode": "lines", "x": [0.0, 0.25, null]}, {"hoverinfo": "none", "y": [0.0, 0.0, null], "line": {"color": "rgb(192, 192, 192)", "width": 2}, "mode": "lines", "x": [0.25, 0.75, null]}, {"hoverinfo": "none", "y": [0.5, 0.0, null], "line": {"color": "rgb(192, 192, 192)", "width": 2}, "mode": "lines", "x": [1.0, 0.75, null]}, {"y": [0.5], "x": [0.5], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["6"]}, {"y": [0.85], "x": [0.5], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["11"]}, {"y": [0.35], "x": [0.25], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["6"]}, {"y": [0.35], "x": [0.75], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["20"]}, {"y": [1.0], "x": [0.25], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["6"]}, {"y": [1.0], "x": [0.75], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["21"]}, {"y": [0.5], "x": [0.0], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["21"]}, {"y": [0.0], "x": [0.25], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {" ...
#             {"sliders": [{"currentvalue": {"visible": false}, "steps": [{"label": "", "args": [[0], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}, {"label": "", "args": [[1], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}, {"label": "", "args": [[2], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}, {"label": "", "args": [[3], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}, {"label": "", "args": [[4], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}, {"label": "", "args": [[5], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}, {"label": "", "args": [[6], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}, {"label": "", "args": [[7], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}, {"label": "", "args": [[8], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}, {"label": "", "args": [[9], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}]}], "showlegend": false, "margin": {"l": 0, "r": 0, "b": 0, "t": 0}, "yaxis": {"showgrid": false, "zeroline": false, "showticklabels": false}, "height": 436.0, "updatemenus": [{"buttons": [{"label": "Play", "args": [null, {"frame": {"redraw": false}, "fromcurrent": true}], "method": "animate"}, {"label": "Pause", "args": [[null], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}], "showactive": true, "type": "buttons"}], "xaxis": {"showgrid": false, "zeroline": false, "showticklabels": false}, "width": 450.0},
#             {"linkText": "Export to plot.ly", "showLink": false, "displayModeBar": false}
#         ).then(function () {return Plotly.addFrames('673c3568-6fc2-4bb6-b922-c53ee02bdfeb',[{"data": [{"hoverinfo": "none", "y": [0.5, 0.85, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 0.5, null]}, {"hoverinfo": "none", "y": [0.5, 0.35, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 0.25, null]}, {"hoverinfo": "none", "y": [0.5, 0.35, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 0.75, null]}, {"hoverinfo": "none", "y": [0.85, 1.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 0.25, null]}, {"hoverinfo": "none", "y": [0.85, 1.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 0.75, null]}, {"hoverinfo": "none", "y": [0.35, 0.5, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.25, 0.0, null]}, {"hoverinfo": "none", "y": [0.35, 0.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.25, 0.25, null]}, {"hoverinfo": "none", "y": [0.35, 0.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.75, 0.75, null]}, {"hoverinfo": "none", "y": [0.35, 0.5, null], "line": {"color": "

# %%
simulate(g6)
# Out:
# <div id="59c704a4-0274-42dc-8c0b-4dcd44dbffd6" style="height: 436.0px; width: 450.0px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '59c704a4-0274-42dc-8c0b-4dcd44dbffd6',
#             [{"hoverinfo": "none", "y": [0.5, 0.75, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 0.5, null]}, {"hoverinfo": "none", "y": [0.5, 0.25, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 0.25, null]}, {"hoverinfo": "none", "y": [0.5, 0.25, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 0.75, null]}, {"hoverinfo": "none", "y": [0.75, 0.8, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 0.25, null]}, {"hoverinfo": "none", "y": [0.75, 1.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 0.5, null]}, {"hoverinfo": "none", "y": [0.75, 0.8, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.5, 0.75, null]}, {"hoverinfo": "none", "y": [0.25, 0.1, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.25, 0.0, null]}, {"hoverinfo": "none", "y": [0.25, 0.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.25, 0.25, null]}, {"hoverinfo": "none", "y": [0.25, 0.5, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.25, 0.05, null]}, {"hoverinfo": "none", "y": [0.25, 0.5, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.75, 0.95, null]}, {"hoverinfo": "none", "y": [0.25, 0.1, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.75, 1.0, null]}, {"hoverinfo": "none", "y": [0.25, 0.0, null], "line": {"color": "rgb(0, 0, 0)", "width": 2}, "mode": "lines", "x": [0.75, 0.75, null]}, {"hoverinfo": "none", "y": [0.8, 1.0, null], "line": {"color": "rgb(192, 192, 192)", "width": 2}, "mode": "lines", "x": [0.25, 0.5, null]}, {"hoverinfo": "none", "y": [0.8, 0.5, null], "line": {"color": "rgb(192, 192, 192)", "width": 2}, "mode": "lines", "x": [0.25, 0.05, null]}, {"hoverinfo": "none", "y": [1.0, 0.8, null], "line": {"color": "rgb(192, 192, 192)", "width": 2}, "mode": "lines", "x": [0.5, 0.75, null]}, {"hoverinfo": "none", "y": [0.8, 0.5, null], "line": {"color": "rgb(192, 192, 192)", "width": 2}, "mode": "lines", "x": [0.75, 0.95, null]}, {"hoverinfo": "none", "y": [0.5, 0.1, null], "line": {"color": "rgb(192, 192, 192)", "width": 2}, "mode": "lines", "x": [0.05, 0.0, null]}, {"hoverinfo": "none", "y": [0.1, 0.0, null], "line": {"color": "rgb(192, 192, 192)", "width": 2}, "mode": "lines", "x": [0.0, 0.25, null]}, {"hoverinfo": "none", "y": [0.0, 0.0, null], "line": {"color": "rgb(192, 192, 192)", "width": 2}, "mode": "lines", "x": [0.25, 0.75, null]}, {"hoverinfo": "none", "y": [0.5, 0.1, null], "line": {"color": "rgb(192, 192, 192)", "width": 2}, "mode": "lines", "x": [0.95, 1.0, null]}, {"hoverinfo": "none", "y": [0.1, 0.0, null], "line": {"color": "rgb(192, 192, 192)", "width": 2}, "mode": "lines", "x": [1.0, 0.75, null]}, {"y": [0.5], "x": [0.5], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["21"]}, {"y": [0.75], "x": [0.5], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["23"]}, {"y": [0.25], "x": [0.25], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["10"]}, {"y": [0.25], "x": [0.75], "textfont": {"color": "rgb(0, 0, 0)"}, "hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 25}, "textposition": "middle center", "mode": "markers+text", "text": ["17"]}, {"y": [0.8], "x": [0.25], "textfont": {"color": "rgb( ...
#             {"sliders": [{"currentvalue": {"visible": false}, "steps": [{"label": "", "args": [[0], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}, {"label": "", "args": [[1], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}, {"label": "", "args": [[2], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}, {"label": "", "args": [[3], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}, {"label": "", "args": [[4], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}, {"label": "", "args": [[5], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}, {"label": "", "args": [[6], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}, {"label": "", "args": [[7], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}, {"label": "", "args": [[8], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}, {"label": "", "args": [[9], {"frame": {"redraw": false}, "mode": "immediate"}], "method": "animate"}]}], "showlegend": false, "margin": {"l": 0, "r": 0, "b": 0, "t": 0}, "yaxis": {"showgrid": false, "zeroline": false, "showticklabels": false}, "height": 436.0, "updatemenus": [{"buttons": [{"label": "Play", "args": [null, {"frame": {"redraw": false}, "fromcurrent

# %% [markdown]
# ## Avançado
#
# Na consolidação do módulo de centralidade, você pode atingir conceito avançado no objetivo **traduzir conceitos sociológicos para teoria dos grafos e algoritmos em grafos** se adicionar ao código da simulação um *cálculo de lucro acumulado*. Essa adição deve ser entregue na mesma data e deve incluir um comentário que explique *como você distribui o lucro no caso em que a soma das demandas é menor que o dinheiro disponível*.
#
# Entender esse enunciado sozinho faz parte da entrega.
