# %% [markdown]
# # Encontro 02, Parte 3: Algoritmo de Bellman-Ford
#
# Este guia foi escrito para ajudar você a atingir os seguintes objetivos:
#
# * implementar o algoritmo de Bellman-Ford;
# * praticar o uso da biblioteca da disciplina.
#
# Primeiramente, vamos importar a biblioteca:

# %%
import sys
sys.path.append('..')

import socnet as sn
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# A seguir, vamos configurar as propriedades visuais:

# %%
sn.graph_width = 320
sn.graph_height = 180

# %% [markdown]
# Por fim, vamos carregar e visualizar um grafo:

# %%
g = sn.load_graph('3-bellman.gml', has_pos=True)

for n, m in g.edges():
    g.edge[n][m]['label'] = g.edge[n][m]['c']

for n in g.nodes():
    g.node[n]['label'] = str(n)
    
sn.show_graph(g, elab=True, nlab=True)
# Out:
# <div id="227b28ee-0c8f-4394-b78a-6d2c9053df89" style="height: 180px; width: 320px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("227b28ee-0c8f-4394-b78a-6d2c9053df89", [{"line": {"color": "rgb(0, 0, 0)", "width": 2}, "x": [0.0, 0.5, null, 0.46643085439538495, 0.44538388103556675, null, 0.46643085439538495, 0.4285584341548651, null, 0.0, 0.5, null, 0.46643085439538495, 0.4285584341548651, null, 0.46643085439538495, 0.44538388103556675, null, 0.5, 1.0, null, 0.9621212121212122, 0.9288794484132434, null, 0.5, 0.5, null, 0.5, 0.48183994171953776, null, 0.5, 0.5181600582804622, null, 0.5, 1.0, null, 0.9738173240163878, 0.9377166459078401, null, 0.9738173240163878, 0.9639630823912474, null, 1.0, 0.5, null, 0.5378787878787878, 0.5711205515867566, null, 0.5, 1.0, null, 0.9738173240163878, 0.9639630823912474, null, 0.9738173240163878, 0.9377166459078401, null, 0.5, 1.0, null, 0.9621212121212122, 0.9288794484132434, null, 0.9621212121212122, 0.9288794484132434, null, 1.0, 0.0, null, 0.03664774299318793, 0.07340128670201525, null, 0.03664774299318793, 0.06421703965128427, null, 1.0, 1.0, null, 1.0, 1.0181600582804622, null, 1.0, 0.9818399417195378, null], "y": [0.5, 1.0, null, 0.966430854395385, 0.906182816233176, null, 0.966430854395385, 0.967759498957256, null, 0.5, 0.0, null, 0.03356914560461503, 0.032240501042743994, null, 0.03356914560461503, 0.09381718376682407, null, 1.0144927536231885, 1.0144927536231885, null, 1.0144927536231885, 1.049233734681464, null, 1.0, 0.0, null, 0.07246376811594203, 0.13605670738336034, null, 0.07246376811594203, 0.13605670738336034, null, 1.0, 0.0, null, 0.052365351967224576, 0.07430651885030926, null, 0.052365351967224576, 0.12233402455151593, null, 0.9855072463768116, 0.9855072463768116, null, 0.9855072463768116, 0.950766265318536, null, 0.0, 1.0, null, 0.9476346480327754, 0.8776659754484841, null, 0.9476346480327754, 0.9256934811496907, null, 0.0, 0.0, null, 0.0, -0.03474098105827558, null, 0.0, 0.03474098105827558, null, 0.0, 0.5, null, 0.481676128503406, 0.4992073320037643, null, 0.481676128503406, 0.4319835048195859, null, 0.0, 1.0, null, 0.927536231884058, 0.8639432926166397, null, 0.927536231884058, 0.8639432926166397, null], "mode": "lines", "hoverinfo": "none"}, {"text": ["0", "1", "2", "3", "4"], "y": [0.5, 1.0, 1.0, 0.0, 0.0], "marker": {"line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 20, "color": "rgb(255, 255, 255)"}, "textposition": "middle center", "x": [0.0, 0.5, 1.0, 0.5, 1.0], "hoverinfo": "none", "mode": "markers+text", "textfont": {"color": "rgb(0, 0, 0)"}}, {"text": [6, 7, 5, 8, -4, -2, -3, 9, 2, 7], "y": [0.783569145604615, 0.28356914560461505, 1.0869565217391306, 0.5, 0.518323871496594, 0.9130434782608696, 0.518323871496594, 0.07246376811594203, 0.19763464803277542, 0.5], "textposition": "middle center", "x": [0.21643085439538495, 0.28356914560461505, 0.75, 0.5378787878787878, 0.786647742993188, 0.75, 0.713352257006812, 0.75, 0.4738173240163877, 0.9621212121212122], "hoverinfo": "none", "mode": "text", "textfont": {"color": "rgb(0, 0, 0)"}}], {"margin": {"l": 0, "r": 0, "t": 0, "b": 0}, "showlegend": false, "yaxis": {"showgrid": false, "zeroline": false, "showticklabels": false}, "height": 180, "width": 320, "xaxis": {"showgrid": false, "zeroline": false, "showticklabels": false}}, {"showLink": false, "displayModeBar": false, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# ## Passeios de custo mínimo
#
# O arquivo atribui `c` às arestas. Formalmente, esse atributo é uma função que mapeia pares de nós a reais:
#
# $c \colon N \times N \rightarrow \mathbb{R}$.
#
# O **custo** de um passeio $\langle n_0, n_1, \ldots, n_{k-1} \rangle$ é
#
# $\sum^{k-2}_{i=0} c(n_i, n_{i+1})$.
#
# Um passeio de origem $s$ e destino $t$ tem **custo mínimo** se não existe outro passeio de origem $s$ e destino $t$ de custo menor. Note que podem existir múltiplos passeios de custo mínimo.
#
# A **distância ponderada** de $s$ a $t$ é o custo mínimo de um passeio de origem $s$ e destino $t$. Por completude, dizemos que a distância ponderada de $s$ a $t$ é $\infty$ se não existe passeio de origem $s$ e destino $t$.
#
# ## Algoritmo de Bellman-Ford
#
# Dado um nó $s$, podemos eficientemente calcular as distâncias ponderadas desse a todos os outros nós do grafo usando o **algoritmo de Bellman-Ford**. A ideia desse algoritmo é diferente da ideia do algoritmo de busca em largura, mas também é simples: inicializamos a distância de $s$ como $0$, inicializamos a distância dos outros nós como $\infty$ e verificamos todas as arestas. Para cada aresta $(n, m)$, se a distância de $m$ for maior que a distância de $n$ mais o custo de $(n, m)$, essa soma passa a ser a nova distância de $m$.
#
# É possível demonstrar matematicamente esse laço precisa ser repetido não mais que $|N|-1$ vezes, onde $|N|$ é a quantidade de nós.

# %%
from math import inf, isinf

s = 0

for n in g.nodes():
    g.node[n]['d'] = inf

g.node[s]['d'] = 0

for i in range(g.number_of_nodes() - 1):
    for n, m in g.edges():
        d = g.node[n]['d'] + g.edge[n][m]['c']

        if g.node[m]['d'] > d:
            g.node[m]['d'] = d

for n in g.nodes():
    print('distância de {}: {}'.format(n, g.node[n]['d']))
# Out:
# distância de 0: 0
# distância de 1: 2
# distância de 2: 4
# distância de 3: 7
# distância de 4: -2

# %% [markdown]
# No entanto, essa demonstração depende de certas hipóteses em relação ao grafo. Tenho uma má e uma boa notícia:
#
# * a má é que existem grafos em que o algoritmo não funciona, ou seja, devolve uma resposta incorreta;
# * a boa é que, nos grafos em que ele funciona, os passeios de custo mínimo são caminhos de custo mínimo.
#
# ### Exercício 1
#
# Que grafos são esses?

# %% [markdown]
# Esse algoritmo não funciona em laços com custo negativos, pois você poderia repetir infinitamente o passeio, tendo assim um custo infinitamente negativo.
#
# E o algoritmo acaba tendo passeios que são caminhos, pois se repetimos uma aresta, o custo sempre aumentará, pelo fato demonstrado acima, portanto, nunca haverá arestas repetidas, apenas possíveis vértices.

# %% [markdown]
# ### Exercício 2
#
# Monte uma visualização do algoritmo de Bellman-Ford.

# %%
#Snapshot
def snapshot(g, frames):
    for n in g.nodes():
        if isinf(g.node[n]['d']):
            g.node[n]['label'] = '∞'
        else:
            g.node[n]['label'] = str(g.node[n]['d'])

    frame = sn.generate_frame(g, nlab=True)

    frames.append(frame)

# %%
red = (255, 0, 0)  # linha nova
blue = (0, 0, 255) # linha nova
frames = []        # linha nova

sn.reset_node_colors(g) # linha nova
sn.reset_edge_colors(g) # linha nova
snapshot(g, frames)     # linha nova

from math import inf, isinf

s = 0

for n in g.nodes():
    g.node[n]['d'] = inf

g.node[s]['d'] = 0

for i in range(g.number_of_nodes() - 1):
    for n, m in g.edges():
        d = g.node[n]['d'] + g.edge[n][m]['c']
        
        g.edge[n][m]['color'] = red # linha nova
        snapshot(g, frames)  
        
        if g.node[m]['d'] > d:
            g.node[m]['d'] = d
            snapshot(g, frames)                   # linha nova

        g.edge[n][m]['color'] = sn.edge_color # linha nova
        snapshot(g, frames)  

sn.show_animation(frames)
# Out:
# <div id="31e9a03a-b0bb-4b12-a64d-d5c0b42a8c26" style="height: 256.0px; width: 408.0px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '31e9a03a-b0bb-4b12-a64d-d5c0b42a8c26',
#             [{"line": {"color": "rgb(0, 0, 0)", "width": 2}, "x": [0.0, 0.5, null, 0.46643085439538495, 0.44538388103556675, null, 0.46643085439538495, 0.4285584341548651, null], "y": [0.5, 1.0, null, 0.966430854395385, 0.906182816233176, null, 0.966430854395385, 0.967759498957256, null], "mode": "lines", "hoverinfo": "none"}, {"line": {"color": "rgb(0, 0, 0)", "width": 2}, "x": [0.0, 0.5, null, 0.46643085439538495, 0.4285584341548651, null, 0.46643085439538495, 0.44538388103556675, null], "y": [0.5, 0.0, null, 0.03356914560461503, 0.032240501042743994, null, 0.03356914560461503, 0.09381718376682407, null], "mode": "lines", "hoverinfo": "none"}, {"line": {"color": "rgb(0, 0, 0)", "width": 2}, "x": [0.5, 1.0, null, 0.9621212121212122, 0.9288794484132434, null], "y": [1.0144927536231885, 1.0144927536231885, null, 1.0144927536231885, 1.049233734681464, null], "mode": "lines", "hoverinfo": "none"}, {"line": {"color": "rgb(0, 0, 0)", "width": 2}, "x": [0.5, 0.5, null, 0.5, 0.48183994171953776, null, 0.5, 0.5181600582804622, null], "y": [1.0, 0.0, null, 0.07246376811594203, 0.13605670738336034, null, 0.07246376811594203, 0.13605670738336034, null], "mode": "lines", "hoverinfo": "none"}, {"line": {"color": "rgb(0, 0, 0)", "width": 2}, "x": [0.5, 1.0, null, 0.9738173240163878, 0.9377166459078401, null, 0.9738173240163878, 0.9639630823912474, null], "y": [1.0, 0.0, null, 0.052365351967224576, 0.07430651885030926, null, 0.052365351967224576, 0.12233402455151593, null], "mode": "lines", "hoverinfo": "none"}, {"line": {"color": "rgb(0, 0, 0)", "width": 2}, "x": [1.0, 0.5, null, 0.5378787878787878, 0.5711205515867566, null], "y": [0.9855072463768116, 0.9855072463768116, null, 0.9855072463768116, 0.950766265318536, null], "mode": "lines", "hoverinfo": "none"}, {"line": {"color": "rgb(0, 0, 0)", "width": 2}, "x": [0.5, 1.0, null, 0.9738173240163878, 0.9639630823912474, null, 0.9738173240163878, 0.9377166459078401, null], "y": [0.0, 1.0, null, 0.9476346480327754, 0.8776659754484841, null, 0.9476346480327754, 0.9256934811496907, null], "mode": "lines", "hoverinfo": "none"}, {"line": {"color": "rgb(0, 0, 0)", "width": 2}, "x": [0.5, 1.0, null, 0.9621212121212122, 0.9288794484132434, null, 0.9621212121212122, 0.9288794484132434, null], "y": [0.0, 0.0, null, 0.0, -0.03474098105827558, null, 0.0, 0.03474098105827558, null], "mode": "lines", "hoverinfo": "none"}, {"line": {"color": "rgb(0, 0, 0)", "width": 2}, "x": [1.0, 0.0, null, 0.03664774299318793, 0.07340128670201525, null, 0.03664774299318793, 0.06421703965128427, null], "y": [0.0, 0.5, null, 0.481676128503406, 0.4992073320037643, null, 0.481676128503406, 0.4319835048195859, null], "mode": "lines", "hoverinfo": "none"}, {"line": {"color": "rgb(0, 0, 0)", "width": 2}, "x": [1.0, 1.0, null, 1.0, 1.0181600582804622, null, 1.0, 0.9818399417195378, null], "y": [0.0, 1.0, null, 0.927536231884058, 0.8639432926166397, null, 0.927536231884058, 0.8639432926166397, null], "mode": "lines", "hoverinfo": "none"}, {"text": ["0"], "y": [0.5], "marker": {"line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 20, "color": "rgb(255, 255, 255)"}, "textposition": "middle center", "x": [0.0], "hoverinfo": "none", "mode": "markers+text", "textfont": {"color": "rgb(0, 0, 0)"}}, {"text": ["2"], "y": [1.0], "marker": {"line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 20, "color": "rgb(255, 255, 255)"}, "textposition": "middle center", "x": [0.5], "hoverinfo": "none", "mode": "markers+text", "textfont": {"color": "rgb(0, 0, 0)"}}, {"text": ["4"], "y": [1.0], "marker": {"line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 20, "color": "rgb(255, 255, 255)"}, "textposition": "middle center", "x": [1.0], "hoverinfo": "none", "mode": "markers+text", "textfont": {"color": "rgb(0, 0, 0)"}}, {"text": ["7"], "y": [0.0], "marker": {"line": {"color": "rgb(0, 0, 0)", "width": 2}, "size": 20, "color": "rgb(255, 255, 255)"}, "textposition": "middle center", "x": [0.5], "hoverinfo": "none", "mode": "markers+text", "textfont":  ...
#             {"margin": {"l": 0, "r": 0, "t": 0, "b": 0}, "sliders": [{"currentvalue": {"visible": false}, "steps": [{"method": "animate", "label": "", "args": [[0], {"mode": "immediate", "frame": {"redraw": false}}]}, {"method": "animate", "label": "", "args": [[1], {"mode": "immediate", "frame": {"redraw": false}}]}, {"method": "animate", "label": "", "args": [[2], {"mode": "immediate", "frame": {"redraw": false}}]}, {"method": "animate", "label": "", "args": [[3], {"mode": "immediate", "frame": {"redraw": false}}]}, {"method": "animate", "label": "", "args": [[4], {"mode": "immediate", "frame": {"redraw": false}}]}, {"method": "animate", "label": "", "args": [[5], {"mode": "immediate", "frame": {"redraw": false}}]}, {"method": "animate", "label": "", "args": [[6], {"mode": "immediate", "frame": {"redraw": false}}]}, {"method": "animate", "label": "", "args": [[7], {"mode": "immediate", "frame": {"redraw": false}}]}, {"method": "animate", "label": "", "args": [[8], {"mode": "immediate", "frame": {"redraw": false}}]}, {"method": "animate", "label": "", "args": [[9], {"mode": "immediate", "frame": {"redraw": false}}]}, {"method": "animate", "label": "", "args": [[10], {"mode": "immediate", "frame": {"redraw": false}}]}, {"method": "animate", "label": "", "args": [[11], {"mode": "immediate", "frame": {"redraw": false}}]}, {"method": "animate", "label": "", "args": [[12], {"mode": "immediate", "frame": {"redraw": false}}]}, {"method": "animate", "label": "", "args": [[13], {"mode": "immediate", "frame": {"redraw": false}}]}, {"method": "animate", "label": "", "args": [[14], {"mode": "immediate", "frame": {"redraw": false}}]}, {"method": "animate", "label": "", "args": [[15], {"mode": "immediate", "frame": {"redraw": false}}]}, {"method": "animate", "label": "", "args": [[16], {"mode": "immediate", "frame": {"redraw": false}}]}, {"method": "animate", "label": "", "args": [[17], {"mode": "immediate", "frame": {"redraw": false}}]}, {"method": "animate", "label": "", "args": [[18], {"mode": "immediate", "frame": {"redraw": false}}]}, {"method": "animate", "label": "", "args": [[19], {"mode": "immediate", "frame": {"redraw": false}}]}, {"method": "animate", "label": "", "args": [[20], {"mode": "immediate", "frame": {"redraw": false}}]}, {"method": "animate", "label": "", "args": [[21], {"mode": "immediate", "frame": {"redraw": false}}]}, {"method": "animate", "label": "", "args": [[22], {"mode": "immediate", "frame": {"redraw": false}}]}, {"method": "animate", "label": "", "args": [[23], {"mode": "immediate", "frame": {"redraw": false}}]}, {"method": "animate", "label": "", "args": [[24], {"mode": "immediate", "frame": {"redraw": false}}]}, {"method": "animate", "label": "", "args": [[25], {"mode": "immediate", "frame": {"redraw": false}}]}, {"method": "animate", "label": "", "args": [[26], {"mode": "immediate", "frame": {"redraw": false}}]}, {"method": "animate", "label": "", "args": [[27], {"mode": "immediate", "frame": {"redraw": false}}]}, {"method": "animate", "label": "", "args": [[28], {"mode": "immediate", "frame": {"redraw": false}}]}, {"method": "animate", "label": "", "args": [[29], {"mode": "immediate", "frame": {"redraw": false}}]}, {"method": "animate", "label": "", "args": [[30], {"mode": "immediate", "frame": {"redraw": false}}]}, {"method": "animate", "label": "", "args": [[31], {"mode": "imme
